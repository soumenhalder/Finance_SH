# %%
from binomial_tree import *

# %%
# Example Usage
arguments = dict(
initial_price = 20,
interest_rate = 12,
total_time = 0.5,
up_factor = 1.10,
down_factor = 0.9, 
steps = 2 ,
strike_price = 21,
divident_rate=0,
volatality=None,
option_type = 'call'
)
tree = BinomialTree(**arguments)                   
tree.build_tree()
visualize_binomial_tree(tree)
# Out:
# [[20, 0, 1.2821849452741405]]

# %%
arguments=dict(
initial_price = 50,
interest_rate = 5,
total_time = 2,
up_factor = 1.20,
down_factor = 0.8, 
steps = 2,
strike_price = 52,
divident_rate=0,
volatality=None,
option_type = 'put',
option_maturity_type = 'European',
)
tree = BinomialTree(**arguments)                   
tree.build_tree()
visualize_binomial_tree(tree)
# Out:
# [[50, 0, 4.1926542806038585]]

# %%
arguments=dict(
initial_price = 50,
interest_rate = 5,
total_time = 2,
up_factor = 1.20,
down_factor = 0.8, 
steps = 2,
strike_price = 52,
divident_rate=0,
volatality=None,
option_type = 'put',
option_maturity_type = 'American')


tree = BinomialTree(**arguments)                   
tree.build_tree()
visualize_binomial_tree(tree)
# Out:
# [[50, 0, 5.089632474198372]]

# %%
arguments=dict(
initial_price = 50,
interest_rate = 5,
total_time = 2,
steps = 2,
strike_price = 52,
divident_rate=0,
volatality=30,
option_type = 'put',
option_maturity_type = 'American')


tree = BinomialTree(**arguments)                   
tree.build_tree()
visualize_binomial_tree(tree)
# Out:
# [[50, 0, 7.4284019027048345]]

# %%
arguments=dict(
initial_price = 810,
interest_rate = 5,
total_time = 0.5,
steps = 2,
strike_price = 800,
divident_rate=2,
volatality=20,
option_type = 'call',
debug=True)


tree = BinomialTree(**arguments)                   
tree.build_tree()
visualize_binomial_tree(tree)
# Out:
# Probability = 0.5125991278953855, discount factor = 1.0075281954445339, up_factor=1.1051709180756477
# [[810, 0, 53.931342195941454]]
